# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
print("libraries imported!")
# Out:
# libraries imported!

# %%
df=pd.read_csv("cust_satisfaction.csv")

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
mm=df.groupby("Gender")
mm

# %%
male=mm.get_group("Male")

# %%
fe=df.groupby("Gender")

# %%
female=fe.get_group("Female")

# %%
df.head(3)
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0

# %%
# sns.catplot(x='Gender',y='satisfaction',data=df,kind='bar',hue="Gender")

# %%
sns.relplot(x='Gender',y='satisfaction',data=male,kind='line',hue="Customer Type",style="Type of Travel",row="Inflight entertainment")
# plt.title("total_bills vs Tips ")
plt.show()

# %%
pip install requests
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 560.1 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.5/1.8 MB 560.1 kB/s eta 0:00:03
#    ----------- ---------------------------- 0.5/1.8 MB 560.1 kB/s eta 0:00:03
#    ----------------- ---------------------- 0.8/1.8 MB 441.7 kB/s eta 0:00:03
#    ----------------- ---------------------- 0.8/1.8 MB 441.7 kB/s eta 0:00:03
#    ----------------- ---------------------- 0.8/1.8 MB 441.7 kB/s eta 0:00:03
#    ---------------------- ----------------- 1.0/1.8 MB 402.7 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.0/1.8 MB 402.7 kB/s eta 0:00:02
# ...

# %%
pip install io
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement io (from versions: none)
# ERROR: No matching distribution found for io

# %%
import requests 
import pandas as pd 
from io import BytesIO

r=requests.get("https://docs.google.com/spreadsheets/d/12KIKsVIT29Nu0jJGC5t2Guep1Bn63sMoU6KL-CcfwIE/edit?gid=0#gid=0")
data=r.content
df=pd.read_csv(BytesIO(data),index_col=0,parse_dates=["Quradate"])
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 7
#       5 r=requests.get("https://docs.google.com/spreadsheets/d/12KIKsVIT29Nu0jJGC5t2Guep1Bn63sMoU6KL-CcfwIE/edit?gid=0#gid=0")
#       6 data=r.content
# ----> 7 df=pd.read_csv(BytesIO(data),index_col=0,parse_dates=["Quradate"])
#       8 df.head()
#
# ...
